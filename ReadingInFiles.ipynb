# %%
import pandas as pd

# %%
# Unicode Error : Python misreads the file path because backslashes (\) are treated as escape characters (like \U, \n).
# The error occurred because Windows file paths use backslashes (\). In Python strings, backslashes start Unicode escape sequences (for example \U). Python tried to interpret \Users as a Unicode escape and failed, so it raised a Unicode error.
# pd.read_csv("C:\Users\ANANYA\OneDrive\Desktop\pandas\countries of the world.csv")

#Fix: use raw string by adding r before the string
pd.read_csv(r"C:\Users\ANANYA\OneDrive\Desktop\pandas\countries of the world.csv")
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
# If our csv doesnt have column values in it we name then we can using names paramtere
pd.read_csv(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.csv",names=["Country","Data"])
# Out:
#              Country                                 Data
# 0            Country                               Region
# 1       Afghanistan         ASIA (EX. NEAR EAST)
# 2           Albania   EASTERN EUROPE
# 3           Algeria   NORTHERN AFRICA
# 4    American Samoa   OCEANIA
# ..               ...                                  ...
# 223       West Bank   NEAR EAST
# 224  Western Sahara   NORTHERN AFRICA
# 225           Yemen   NEAR EAST
# 226          Zambia   SUB-SAHARAN AFRICA
# 227        Zimbabwe   SUB-SAHARAN AFRICA
#
# [228 rows x 2 columns]

# %%
pd.read_csv(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.csv",header=None)
# header= None will assign num from 0 to n as column names and if header is 1 then it will assign first row as column names
# Out:
#                    0                                    1
# 0            Country                               Region
# 1       Afghanistan         ASIA (EX. NEAR EAST)
# 2           Albania   EASTERN EUROPE
# 3           Algeria   NORTHERN AFRICA
# 4    American Samoa   OCEANIA
# ..               ...                                  ...
# 223       West Bank   NEAR EAST
# 224  Western Sahara   NORTHERN AFRICA
# 225           Yemen   NEAR EAST
# 226          Zambia   SUB-SAHARAN AFRICA
# 227        Zimbabwe   SUB-SAHARAN AFRICA
#
# [228 rows x 2 columns]

# %%
# when read a file assign it to a variable to use it later
data = pd.read_csv(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.csv")
data
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#Read text files: if i use csv it wont import properly it has country \t
# pd.read_csv(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.txt")

# with read_csv:for this we use sep
pd.read_csv(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.txt",sep="\t")
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#read_table
df = pd.read_table(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.txt")
df

# by default read_table uses \t as separator
# to read csv we use sep=','
# df = pd.read_table(r"C:\\Users\\ANANYA\\OneDrive\\Desktop\\pandas\\countries of the world.csv",sep=',')  
# df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#read_json for json files
df = pd.read_json(r"C:\Users\ANANYA\OneDrive\Desktop\pandas\json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
#Read in excel files
df1 = pd.read_excel(r"C:\Users\ANANYA\OneDrive\Desktop\pandas\world_population_excel_workbook.xlsx")
df1
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
# There are two sheets in the excel file, to read specific sheet use sheet_name parameter to specify sheet name
df = pd.read_excel(r"C:\Users\ANANYA\OneDrive\Desktop\pandas\world_population_excel_workbook.xlsx",sheet_name='Sheet1')

# if dont know sheet name then use indexing
# df = pd.read_excel(r"C:\Users\ANANYA\OneDrive\Desktop\pandas\world_population_excel_workbook.xlsx",sheet_name=1)
df
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
# we cant see want to see ... content bcoz of some default settings
pd.set_option('display.max_rows',250)  # to see all rows
pd.set_option('display.max_columns',7)  # to see all columns
#to reset to default
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
df1.info() #quick breakdown of our data
#234 values in that column no missing values & mem usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df1.shape  # to see shape of dataframe (rows,columns)

df1.head()  # first 5 rows
# df1.head(10)

df1.tail()  # last 5 rows
# Out:
#      Rank CCA3            Country    Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna   Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El AaiÃºn    Africa           575986
# 231    46  YEM              Yemen      Sanaa      Asia         33696614
# 232    63  ZMB             Zambia     Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe     Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# ...

# %%
# we want to take a look at only particular column then
df1['Rank']  # to see only Rank column
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
#loc : to access a group of rows and columns by labels or a boolean array
df1.loc[0]  # first row
df1.loc['India']  # row with index label 'India'
# Out:
# Rank                                    36
# CCA3                                   AFG
# Country                        Afghanistan
# Capital                              Kabul
# Continent                             Asia
# 2022 Population                   41128771
# 2020 Population                   38972230
# 2015 Population                   33753499
# 2010 Population                   28189672
# 2000 Population                   19542982
# 1990 Population                   10694796
# 1980 Population                   12486631
# 1970 Population                   10752971
# Area (kmÂ²)                         652230
# Density (per kmÂ²)                 63.0587
# Growth Rate                         1.0257
# World Population Percentage           0.52
# Name: 0, dtype: object

# %%
# iloc : to access a group of rows and columns by integer position (index)
df1.iloc[223]  # first row
# Out:
# Rank                                     133
# CCA3                                     URY
# Country                              Uruguay
# Capital                           Montevideo
# Continent                      South America
# 2022 Population                      3422794
# 2020 Population                      3429086
# 2015 Population                      3402818
# 2010 Population                      3352651
# 2000 Population                      3292224
# 1990 Population                      3117012
# 1980 Population                      2953750
# 1970 Population                      2790265
# Area (kmÂ²)                           181034
# Density (per kmÂ²)                   18.9069
# Growth Rate                            0.999
# World Population Percentage             0.04
# Name: 223, dtype: object
